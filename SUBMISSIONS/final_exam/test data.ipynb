# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("genomics_data.txt", sep='\t', skiprows=[0, 1, 2], header=1)
df
# Out:
#    #CHROM     POS           ID REF ALT QUAL FILTER  \
# 0       1  949523  rs786201005   C   T    .      .
# 1       1  949696  rs672601345   C  CG    .      .
# 2       1  949739  rs672601312   G   T    .      .
# 3       1  955597  rs115173026   G   T    .      .
# 4       1  955619  rs201073369   G   C    .      .
# 5       1  957640    rs6657048   C   T    .      .
# 6       1  976059  rs544749044   C   T    .      .
#
#                                       INFO
# 0                  GENEINFO=ISG15;CLNSIG=5
# 1    GENEINFO=ISG15;CLNSIG=5;CLNDBN=Cancer
# 2             GENEINFO=ISG15;CLNDBN=Cancer
# 3    GENEINFO=AGRN;CLNSIG=2; CLNDBN=Cancer
# 4           GENEINFO=AGG;CLNDBN=Heart_dis
# 5  GENEINFO=AGG;CLNSIG=3;CLNDBN=Heart_dis
# 6  GENEINFO=AGG;CLNSIG=0;CLNDBN=Heart_dis
